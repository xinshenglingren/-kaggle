# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
# train_data = pd.read_csv('train.csv',names=range(14))
# test_data = pd.read_csv('test.csv',names=range(13))

# %%
def Get_data(paths):
    train_path, test_path = paths[0], paths[1]
    train_data = pd.read_csv(train_path,names=range(14))
    test_data = pd.read_csv(test_path,names=range(13))
    return train_data,test_data
paths = ['train.csv','test.csv']
train_data, test_data = Get_data(paths)

# %%
labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
              'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss',
              'hours_per_week', 'native_country']
train_data.columns = labels[:]
test_data.columns = labels[:13]

# %%
train_data=train_data.replace(to_replace='?',value=np.nan)#缺失值进行处理
test_data=test_data.replace(to_replace='?',value=np.nan)#缺失值进行处理
train_data
# Out:
#       age workclass  fnlwgt education education_num marital_status  \
# 0       2         5       2         4             3              4
# 1       2         5       3         5             1              3
# 2       1         3       5         4             1              5
# 3       2         3       5         4             4            NaN
# 4       1         3       6         4             8              5
# 5       1         1       5         6             4              5
# 6       1         1       1         5             8              5
# 7       2         3       3         4             1              3
# 8       2       NaN       2         3             1              5
# 9       2         1       7         4             8              5
# 10      1         1       4         5             1            NaN
# 11      1         1       4         4             1              5
# 12      1         5       2         4             3              1
# 13      1         1       3         4             1              2
# 14      1         2       2         3             3              2
# 15      1         5       4         5             4              5
# 16      1         5       3         4             3              2
# 17      1         5       1         2             6              5
# 18      2         5       2         5             4              5
# 19      2         3       4         4             1              5
# 20      2         2       3         5             5              3
# 21      1         5       4         6             3              5
# 22      1         5       3         3             1              5
# 23      2         5       2         4             6              5
# 24      1         1       3         4             1              5
# 25      1         1       3         4             1              5
# 26      2         3       4         6             1              5
# 27      2         1       4         3             1              5
# 28      2         5       2         4             1              5
# 29      2         5       1         1             6            NaN
# ...   ...       ...     ...       ...           ...            ...
# 7164    2         1       6         3             5            NaN
# 7165    1         2       3         5             1              3
# 7166    1       NaN       1         2           NaN            NaN
# 7167    1         4       7         5             8              5
# 7168    2         5       3         4             4              5
# 7169    1         1       3         5             1              5
# 7170    1         5       1         2             9              3
# 7171    2         1       7         3             5              5
# 7172    1         5       2         4             6              5
# 7173    2         5       2         4             9              5
# 7174    1         1       6         4             8              3
# 7175    1         5       3         4             1              3
# 7176    1         3       6         4             9              5
# 7177    1         5       1         2             6              4
# 7178    1         1       5         6             8              3
# 7179    1         1       5         5             1              5
# 7180    1         1       5         1           NaN            NaN
# 7181    2         1       3         4             4              5
# 7182    2         4       4         4             5              5
# 7183    2         4       7         3             8              5
# 7184    1         1       3         4             3              5
# 7185    1         5       1         2             6              5
# 7186    1         5       2         4             6              1
# 7187    1         1       5         3             3              5
# 7188    2         5       2         3             4              1
# 7189    1         1       4         2             3              5
# 7190    2         5       2         5             6              2
# 7191    2         1       7         3             8            NaN
# 7192    2         5       1         2             6              2
# 7193    1         3       4         4             1              3
#
#       occupation relationship  race  sex capital_gain capital_loss  \
# 0              1            1     0    2            3            7
# 1              1            3     0    2            3            7
# 2              1            2     1    1            1            7
# 3              1            2     0    1            1            7
# 4              1            1     0    2            3            7
# 5              2            2     0    1            1            7
# 6              2            3     0    2            1            3
# 7              1            4     3    2            1            3
# 8              1            3     1    1            2            7
# 9              3            2     0    1            2            5
# 10             2            2     0    1            1            7
# 11             2            3     0    1            1            7
# 12             1            1     0    2            3            7
# 13             3            2     0    2            1            7
# 14             1            2     0    2            1            5
# 15             1            1     0    2            3            7
# 16             1            4     0    2            5            7
# 17             1            4     1    3            1            2
# 18             1            1     0    2            3            7
# 19             1            4     2    2            1            3
# 20             1            2     0    2            1            1
# 21             1            1     0    1            4            7
# 22             1            4     0    2            3            3
# 23             1          NaN     0    2            3            6
# 24             2            3     1    2            1            7
# 25             2            3     1    1            1            7
# 26             1            4     1    1            1            7
# 27             2            5     2    1            1            5
# 28             1            5     0    2            1            7
# 29             1          NaN     0    3            3            3
# ...          ...          ...   ...  ...          ...          ...
# 7164           3            2     0    1            1            7
# 7165           2            2     0    2            3            7
# 7166           3          NaN     0    3          NaN            3
# 7167           1            1     0    1            1            7
# 7168           1            2     0    2            2            7
# 7169           3            2     0    2            3            8
# 7170           1            2     1    2            1            7
# 7171           3            2     0    1            1            7
# 7172           1            4     1    3            1            2
# 7173           1            5     0    3            1            7
# 7174           2            4     2    2            3            6
# 7175           1            1     0    1            1            7
# 7176           1            2     0    1            1            7
# 7177           1          NaN     0    3          NaN          NaN
# 7178           3            9     2    1            1            7
# 7179           3            2     0    1            1            7
# 7180           2            3     1    2            1            5
# 7181           2            4     2    2            1            3
# 7182           1            5     4    1            1            7
# 7183           1            1     0    2          NaN            7
# 7184           2            4     2    2            3            5
# 7185           1            3     1    3            3            3
# 7186           1            3     0    3            1            7
# 7187           2            5     1    1            1            7
# 7188           1            1     0    2            3            7
# 7189           2            6     2    1            1            3
# 7190           1            4     0    3            1            2
# 7191           3            2     0    1            2            7
# 7192           1            4     2    3            1            7
# 7193           1            1     0  NaN            3            5
#
#      hours_per_week  native_country
# 0                 1               1
# 1                 1               2
# 2                 1               8
# 3                 1               4
# 4                 1               4
# 5                 1               8
# 6                 2               3
# 7                 1               4
# 8                 1               6
# 9                 2               6
# 10                1               9
# 11                1               8
# 12                1               4
# 13                1               5
# 14                2               8
# 15                1               3
# 16                1               5
# 17                1               1
# 18                1               3
# 19                1               7
# 20                1               3
# 21                1               6
# 22                1               3
# 23                1               1
# 24                1               5
# 25                1               9
# 26                1               8
# 27                2               5
# 28                1               1
# 29                1               1
# ...             ...             ...
# 7164              1               5
# 7165              1               8
# 7166              1               1
# 7167              1               8
# 7168              1               4
# 7169              1               5
# 7170            NaN               1
# 7171              1               2
# 7172              1               5
# 7173              1               7
# 7174              1               7
# 7175              1               8
# 7176            NaN               9
# 7177              1               1
# 7178              1               9
# 7179              1               6
# 7180              2               2
# 7181              1               4
# 7182              1               7
# 7183            NaN               2
# 7184              1               5
# 7185              1               1
# 7186              1               3
# 7187              1               7
# 7188              1               2
# 7189              1               4
# 7190              1               2
# 7191              1               9
# 7192              1               1
# 7193              2               7
#
# [7194 rows x 14 columns]

# %%
def Feature_encode(data):
    for feature in data.columns:
        if data[feature].dtype == 'object':
            data[feature] = pd.Categorical(data[feature]).codes
    return data

# %%
train_data = Feature_encode(train_data)
test_data = Feature_encode(test_data)

# %%
from sklearn import tree
X_train = train_data.iloc[:,:-1]
y_train = train_data.iloc[:,-1]
clf = tree.DecisionTreeClassifier(splitter='random')
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='random')

# %%
y_pred = clf.predict(test_data.iloc[:])
X_test = test_data.iloc[ :,:13]
y_test = test_data.iloc[:,-1]
clf.score(X_test,y_test)
# Out:
# 0.02335928809788654
